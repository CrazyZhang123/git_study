# %% [markdown]
# # 1、线性模型  y = w * x
#
# 绘制w和MSE的关系图

# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = [1.0,2.0,3.0]
y_data = [2.0,4.0,6.0]

def forward(x):
    return x * w

def loss(x,y):
    y_pred = forward(x)
    return (y_pred - y)**2

w_list = []
mse_list = []

for w in np.arange(0.0,4.1,0.1):
    print('w=',w)
    l_sum = 0
    for x_val,y_val in zip(x_data,y_data):
        y_pred_val = forward(x_val)
        loss_val = loss(x_val,y_val)
        l_sum += loss_val
        print(f'\t x_val:{x_val},y_val:{y_val},y_pred_val:{y_pred_val},loss_val:{loss_val}')
        
    print(f'MSE=',l_sum/len(x_data))
    w_list.append(w)
    mse_list.append(l_sum/len(x_data))
# Out:
# w= 0.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.0,loss_val:4.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.0,loss_val:16.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.0,loss_val:36.0
# MSE= 18.666666666666668
# w= 0.1
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.1,loss_val:3.61
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.2,loss_val:14.44
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.30000000000000004,loss_val:32.49
# MSE= 16.846666666666668
# w= 0.2
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.2,loss_val:3.24
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.4,loss_val:12.96
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.6000000000000001,loss_val:29.160000000000004
# MSE= 15.120000000000003
# w= 0.30000000000000004
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.30000000000000004,loss_val:2.8899999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.6000000000000001,loss_val:11.559999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.9000000000000001,loss_val:26.009999999999998
# MSE= 13.486666666666665
# w= 0.4
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.4,loss_val:2.5600000000000005
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.8,loss_val:10.240000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.2000000000000002,loss_val:23.04
# MSE= 11.946666666666667
# w= 0.5
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.5,loss_val:2.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.0,loss_val:9.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.5,loss_val:20.25
# MSE= 10.5
# w= 0.6000000000000001
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.6000000000000001,loss_val:1.9599999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.2000000000000002,loss_val:7.839999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.8000000000000003,loss_val:17.639999999999993
# MSE= 9.146666666666663
# w= 0.7000000000000001
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.7000000000000001,loss_val:1.6899999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.4000000000000001,loss_val:6.759999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.1,loss_val:15.209999999999999
# MSE= 7.886666666666666
# w= 0.8
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.8,loss_val:1.44
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.6,loss_val:5.76
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.4000000000000004,loss_val:12.959999999999997
# MSE= 6.719999999999999
# w= 0.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.9,loss_val:1.2100000000000002
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.8,loss_val:4.840000000000001
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.7,loss_val:10.889999999999999
# MSE= 5.646666666666666
# w= 1.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.0,loss_val:1.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.0,loss_val:4.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:3.0,loss_val:9.0
# MSE= 4.666666666666667
# w= 1.1
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.1,loss_val:0.8099999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.2,loss_val:3.2399999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:3.3000000000000003,loss_val:7.289999999999998
# MSE= 3.779999999999999
# w= 1.2000000000000002
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.2000000000000002,loss_val:0.6399999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.4000000000000004,loss_val:2.5599999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:3.6000000000000005,loss_val:5.759999999999997
# MSE= 2.986666666666665
# w= 1.3
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.3,loss_val:0.48999999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.6,loss_val:1.9599999999999997
# 	 x_val:3.0,y_val:6.0,y_pred_val:3.9000000000000004,loss_val:4.409999999999998
# MSE= 2.2866666666666657
# w= 1.4000000000000001
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.4000000000000001,loss_val:0.3599999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.8000000000000003,loss_val:1.4399999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:4.2,loss_val:3.2399999999999993
# MSE= 1.6799999999999995
# w= 1.5
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.5,loss_val:0.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:3.0,loss_val:1.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:4.5,loss_val:2.25
# MSE= 1.1666666666666667
# w= 1.6
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.6,loss_val:0.15999999999999992
# 	 x_val:2.0,y_val:4.0,y_pred_val:3.2,loss_val:0.6399999999999997
# 	 x_val:3.0,y_val:6.0,y_pred_val:4.800000000000001,loss_val:1.4399999999999984
# MSE= 0.746666666666666
# w= 1.7000000000000002
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.7000000000000002,loss_val:0.0899999999999999
# 	 x_val:2.0,y_val:4.0,y_pred_val:3.4000000000000004,loss_val:0.3599999999999996
# 	 x_val:3.0,y_val:6.0,y_pred_val:5.1000000000000005,loss_val:0.809999999999999
# MSE= 0.4199999999999995
# w= 1.8
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.8,loss_val:0.03999999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:3.6,loss_val:0.15999999999999992
# 	 x_val:3.0,y_val:6.0,y_pred_val:5.4,loss_val:0.3599999999999996
# MSE= 0.1866666666666665
# w= 1.9000000000000001
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.9000000000000001,loss_val:0.009999999999999974
# 	 x_val:2.0,y_val:4.0,y_pred_val:3.8000000000000003,loss_val:0.0399999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:5.7,loss_val:0.0899999999999999
# MSE= 0.046666666666666586
# w= 2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0,loss_val:0.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:4.0,loss_val:0.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:6.0,loss_val:0.0
# MSE= 0.0
# w= 2.1
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.1,loss_val:0.010000000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:4.2,loss_val:0.04000000000000007
# 	 x_val:3.0,y_val:6.0,y_pred_val:6.300000000000001,loss_val:0.09000000000000043
# MSE= 0.046666666666666835
# w= 2.2
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.2,loss_val:0.04000000000000007
# 	 x_val:2.0,y_val:4.0,y_pred_val:4.4,loss_val:0.16000000000000028
# 	 x_val:3.0,y_val:6.0,y_pred_val:6.6000000000000005,loss_val:0.36000000000000065
# MSE= 0.18666666666666698
# w= 2.3000000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.3000000000000003,loss_val:0.09000000000000016
# 	 x_val:2.0,y_val:4.0,y_pred_val:4.6000000000000005,loss_val:0.36000000000000065
# 	 x_val:3.0,y_val:6.0,y_pred_val:6.9,loss_val:0.8100000000000006
# MSE= 0.42000000000000054
# w= 2.4000000000000004
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.4000000000000004,loss_val:0.16000000000000028
# 	 x_val:2.0,y_val:4.0,y_pred_val:4.800000000000001,loss_val:0.6400000000000011
# 	 x_val:3.0,y_val:6.0,y_pred_val:7.200000000000001,loss_val:1.4400000000000026
# MSE= 0.7466666666666679
# w= 2.5
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.5,loss_val:0.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:5.0,loss_val:1.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:7.5,loss_val:2.25
# MSE= 1.1666666666666667
# w= 2.6
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.6,loss_val:0.3600000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:5.2,loss_val:1.4400000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:7.800000000000001,loss_val:3.2400000000000024
# MSE= 1.6800000000000008
# w= 2.7
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.7,loss_val:0.49000000000000027
# 	 x_val:2.0,y_val:4.0,y_pred_val:5.4,loss_val:1.960000000000001
# 	 x_val:3.0,y_val:6.0,y_pred_val:8.100000000000001,loss_val:4.410000000000006
# MSE= 2.2866666666666693
# w= 2.8000000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.8000000000000003,loss_val:0.6400000000000005
# 	 x_val:2.0,y_val:4.0,y_pred_val:5.6000000000000005,loss_val:2.560000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:8.4,loss_val:5.760000000000002
# MSE= 2.986666666666668
# w= 2.9000000000000004
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.9000000000000004,loss_val:0.8100000000000006
# 	 x_val:2.0,y_val:4.0,y_pred_val:5.800000000000001,loss_val:3.2400000000000024
# 	 x_val:3.0,y_val:6.0,y_pred_val:8.700000000000001,loss_val:7.290000000000005
# MSE= 3.780000000000003
# w= 3.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.0,loss_val:1.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.0,loss_val:4.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:9.0,loss_val:9.0
# MSE= 4.666666666666667
# w= 3.1
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.1,loss_val:1.2100000000000002
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.2,loss_val:4.840000000000001
# 	 x_val:3.0,y_val:6.0,y_pred_val:9.3,loss_val:10.890000000000004
# MSE= 5.646666666666668
# w= 3.2
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.2,loss_val:1.4400000000000004
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.4,loss_val:5.760000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:9.600000000000001,loss_val:12.96000000000001
# MSE= 6.720000000000003
# w= 3.3000000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.3000000000000003,loss_val:1.6900000000000006
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.6000000000000005,loss_val:6.7600000000000025
# 	 x_val:3.0,y_val:6.0,y_pred_val:9.9,loss_val:15.210000000000003
# MSE= 7.886666666666668
# w= 3.4000000000000004
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.4000000000000004,loss_val:1.960000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.800000000000001,loss_val:7.840000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.200000000000001,loss_val:17.640000000000008
# MSE= 9.14666666666667
# w= 3.5
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.5,loss_val:2.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.0,loss_val:9.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.5,loss_val:20.25
# MSE= 10.5
# w= 3.6
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.6,loss_val:2.5600000000000005
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.2,loss_val:10.240000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.8,loss_val:23.040000000000006
# MSE= 11.94666666666667
# w= 3.7
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.7,loss_val:2.8900000000000006
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.4,loss_val:11.560000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.100000000000001,loss_val:26.010000000000016
# MSE= 13.486666666666673
# w= 3.8000000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.8000000000000003,loss_val:3.240000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.6000000000000005,loss_val:12.960000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.4,loss_val:29.160000000000004
# MSE= 15.120000000000005
# w= 3.9000000000000004
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.9000000000000004,loss_val:3.610000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.800000000000001,loss_val:14.440000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.700000000000001,loss_val:32.49000000000001
# MSE= 16.84666666666667
# w= 4.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.0,loss_val:4.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.0,loss_val:16.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.0,loss_val:36.0
# MSE= 18.666666666666668

# %%
plt.plot(w_list,mse_list)
plt.xlabel('w')
plt.ylabel('MSE Loss')
plt.show()
# Out:
# Text(0.5, 0, 'w')
# Text(0, 0.5, 'MSE Loss')

# %% [markdown]
# # 2、线性模型 y = w * x + b

# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = [1.0,2.0,3.0]
y_data = [2.0,4.0,6.0]

def forward(x):
    return x * w + b

def loss(x,y):
    y_pred = forward(x)
    return (y_pred - y)**2

w_list = []
b_list = []
mse_list = []

for w in np.arange(0.0,4.1,0.1):
    for b in np.arange(-2,2.1,0.1):
        print('w=',w,',b=',b)
        l_sum = 0
        for x_val,y_val in zip(x_data,y_data):
            y_pred_val = forward(x_val)
            loss_val = loss(x_val,y_val)
            l_sum += loss_val
            print(f'\t x_val:{x_val},y_val:{y_val},y_pred_val:{y_pred_val},loss_val:{loss_val}')
            
        print(f'MSE=',l_sum/len(x_data))
        w_list.append(w)
        b_list.append(b)
        mse_list.append(l_sum/len(x_data))
# Out:
# w= 0.0 ,b= -2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:-2.0,loss_val:16.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:-2.0,loss_val:36.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:-2.0,loss_val:64.0
# MSE= 38.666666666666664
# w= 0.0 ,b= -1.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.9,loss_val:15.209999999999999
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.9,loss_val:34.81
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.9,loss_val:62.410000000000004
# MSE= 37.47666666666667
# w= 0.0 ,b= -1.7999999999999998
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.7999999999999998,loss_val:14.44
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.7999999999999998,loss_val:33.64
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.7999999999999998,loss_val:60.839999999999996
# MSE= 36.306666666666665
# w= 0.0 ,b= -1.6999999999999997
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.6999999999999997,loss_val:13.689999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.6999999999999997,loss_val:32.489999999999995
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.6999999999999997,loss_val:59.28999999999999
# MSE= 35.15666666666666
# w= 0.0 ,b= -1.5999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.5999999999999996,loss_val:12.959999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.5999999999999996,loss_val:31.359999999999996
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.5999999999999996,loss_val:57.76
# MSE= 34.026666666666664
# w= 0.0 ,b= -1.4999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.4999999999999996,loss_val:12.249999999999996
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.4999999999999996,loss_val:30.25
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.4999999999999996,loss_val:56.25
# MSE= 32.916666666666664
# w= 0.0 ,b= -1.3999999999999995
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.3999999999999995,loss_val:11.559999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.3999999999999995,loss_val:29.159999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.3999999999999995,loss_val:54.75999999999999
# MSE= 31.826666666666664
# w= 0.0 ,b= -1.2999999999999994
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.2999999999999994,loss_val:10.889999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.2999999999999994,loss_val:28.08999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.2999999999999994,loss_val:53.289999999999985
# MSE= 30.756666666666657
# w= 0.0 ,b= -1.1999999999999993
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.1999999999999993,loss_val:10.239999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.1999999999999993,loss_val:27.039999999999992
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.1999999999999993,loss_val:51.83999999999999
# MSE= 29.70666666666666
# w= 0.0 ,b= -1.0999999999999992
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.0999999999999992,loss_val:9.609999999999996
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.0999999999999992,loss_val:26.009999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.0999999999999992,loss_val:50.41
# MSE= 28.676666666666662
# w= 0.0 ,b= -0.9999999999999991
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.9999999999999991,loss_val:8.999999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.9999999999999991,loss_val:24.999999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.9999999999999991,loss_val:48.999999999999986
# MSE= 27.666666666666657
# w= 0.0 ,b= -0.899999999999999
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.899999999999999,loss_val:8.409999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.899999999999999,loss_val:24.009999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.899999999999999,loss_val:47.60999999999998
# MSE= 26.67666666666665
# w= 0.0 ,b= -0.7999999999999989
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.7999999999999989,loss_val:7.839999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.7999999999999989,loss_val:23.03999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.7999999999999989,loss_val:46.23999999999999
# MSE= 25.70666666666666
# w= 0.0 ,b= -0.6999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.6999999999999988,loss_val:7.289999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.6999999999999988,loss_val:22.089999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.6999999999999988,loss_val:44.88999999999999
# MSE= 24.75666666666666
# w= 0.0 ,b= -0.5999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.5999999999999988,loss_val:6.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.5999999999999988,loss_val:21.15999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.5999999999999988,loss_val:43.55999999999998
# MSE= 23.826666666666654
# w= 0.0 ,b= -0.49999999999999867
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.49999999999999867,loss_val:6.249999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.49999999999999867,loss_val:20.249999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.49999999999999867,loss_val:42.24999999999998
# MSE= 22.916666666666654
# w= 0.0 ,b= -0.3999999999999986
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.3999999999999986,loss_val:5.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.3999999999999986,loss_val:19.35999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.3999999999999986,loss_val:40.95999999999998
# MSE= 22.026666666666653
# w= 0.0 ,b= -0.2999999999999985
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.2999999999999985,loss_val:5.289999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.2999999999999985,loss_val:18.48999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.2999999999999985,loss_val:39.68999999999998
# MSE= 21.156666666666656
# w= 0.0 ,b= -0.1999999999999984
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.1999999999999984,loss_val:4.839999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.1999999999999984,loss_val:17.639999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.1999999999999984,loss_val:38.43999999999998
# MSE= 20.306666666666654
# w= 0.0 ,b= -0.09999999999999831
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.09999999999999831,loss_val:4.409999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.09999999999999831,loss_val:16.80999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.09999999999999831,loss_val:37.20999999999997
# MSE= 19.47666666666665
# w= 0.0 ,b= 1.7763568394002505e-15
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.7763568394002505e-15,loss_val:3.999999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.7763568394002505e-15,loss_val:15.999999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.7763568394002505e-15,loss_val:35.99999999999998
# MSE= 18.666666666666654
# w= 0.0 ,b= 0.10000000000000187
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.10000000000000187,loss_val:3.6099999999999928
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.10000000000000187,loss_val:15.209999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.10000000000000187,loss_val:34.80999999999998
# MSE= 17.876666666666654
# w= 0.0 ,b= 0.20000000000000195
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.20000000000000195,loss_val:3.239999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.20000000000000195,loss_val:14.439999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.20000000000000195,loss_val:33.63999999999998
# MSE= 17.10666666666665
# w= 0.0 ,b= 0.30000000000000204
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.30000000000000204,loss_val:2.889999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.30000000000000204,loss_val:13.689999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.30000000000000204,loss_val:32.489999999999974
# MSE= 16.35666666666665
# w= 0.0 ,b= 0.40000000000000213
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.40000000000000213,loss_val:2.5599999999999934
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.40000000000000213,loss_val:12.959999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.40000000000000213,loss_val:31.359999999999975
# MSE= 15.626666666666651
# w= 0.0 ,b= 0.5000000000000022
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.5000000000000022,loss_val:2.2499999999999933
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.5000000000000022,loss_val:12.249999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.5000000000000022,loss_val:30.24999999999998
# MSE= 14.916666666666652
# w= 0.0 ,b= 0.6000000000000023
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.6000000000000023,loss_val:1.9599999999999935
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.6000000000000023,loss_val:11.559999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.6000000000000023,loss_val:29.159999999999975
# MSE= 14.22666666666665
# w= 0.0 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.7000000000000024,loss_val:1.6899999999999937
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.7000000000000024,loss_val:10.889999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.7000000000000024,loss_val:28.08999999999997
# MSE= 13.55666666666665
# w= 0.0 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.8000000000000025,loss_val:1.439999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.8000000000000025,loss_val:10.239999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.8000000000000025,loss_val:27.039999999999974
# MSE= 12.906666666666652
# w= 0.0 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.9000000000000026,loss_val:1.2099999999999944
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.9000000000000026,loss_val:9.609999999999983
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.9000000000000026,loss_val:26.009999999999977
# MSE= 12.276666666666651
# w= 0.0 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.0000000000000027,loss_val:0.9999999999999947
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.0000000000000027,loss_val:8.999999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.0000000000000027,loss_val:24.99999999999997
# MSE= 11.66666666666665
# w= 0.0 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.1000000000000028,loss_val:0.8099999999999951
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.1000000000000028,loss_val:8.409999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.1000000000000028,loss_val:24.00999999999997
# MSE= 11.076666666666648
# w= 0.0 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.2000000000000028,loss_val:0.6399999999999955
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.2000000000000028,loss_val:7.839999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.2000000000000028,loss_val:23.039999999999974
# MSE= 10.506666666666652
# w= 0.0 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.300000000000003,loss_val:0.4899999999999959
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.300000000000003,loss_val:7.289999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.300000000000003,loss_val:22.089999999999975
# MSE= 9.956666666666651
# w= 0.0 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.400000000000003,loss_val:0.3599999999999964
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.400000000000003,loss_val:6.759999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.400000000000003,loss_val:21.15999999999997
# MSE= 9.42666666666665
# w= 0.0 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.500000000000003,loss_val:0.2499999999999969
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.500000000000003,loss_val:6.249999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.500000000000003,loss_val:20.249999999999968
# MSE= 8.91666666666665
# w= 0.0 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.6000000000000032,loss_val:0.15999999999999745
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.6000000000000032,loss_val:5.759999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.6000000000000032,loss_val:19.35999999999997
# MSE= 8.42666666666665
# w= 0.0 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.7000000000000033,loss_val:0.08999999999999803
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.7000000000000033,loss_val:5.289999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.7000000000000033,loss_val:18.489999999999977
# MSE= 7.956666666666654
# w= 0.0 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.8000000000000034,loss_val:0.03999999999999865
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.8000000000000034,loss_val:4.839999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.8000000000000034,loss_val:17.639999999999972
# MSE= 7.506666666666651
# w= 0.0 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.9000000000000035,loss_val:0.009999999999999308
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.9000000000000035,loss_val:4.409999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.9000000000000035,loss_val:16.809999999999967
# MSE= 7.07666666666665
# w= 0.0 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0000000000000036,loss_val:1.262177448353619e-29
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.0000000000000036,loss_val:3.999999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.0000000000000036,loss_val:15.999999999999972
# MSE= 6.666666666666653
# w= 0.1 ,b= -2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.9,loss_val:15.209999999999999
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.8,loss_val:33.64
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.7,loss_val:59.290000000000006
# MSE= 36.046666666666674
# w= 0.1 ,b= -1.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.7999999999999998,loss_val:14.44
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.7,loss_val:32.49
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.5999999999999999,loss_val:57.76
# MSE= 34.89666666666667
# w= 0.1 ,b= -1.7999999999999998
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.6999999999999997,loss_val:13.689999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.5999999999999999,loss_val:31.359999999999996
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.4999999999999998,loss_val:56.25
# MSE= 33.766666666666666
# w= 0.1 ,b= -1.6999999999999997
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.5999999999999996,loss_val:12.959999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.4999999999999998,loss_val:30.25
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.3999999999999997,loss_val:54.75999999999999
# MSE= 32.65666666666666
# w= 0.1 ,b= -1.5999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.4999999999999996,loss_val:12.249999999999996
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.3999999999999997,loss_val:29.159999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.2999999999999996,loss_val:53.29
# MSE= 31.566666666666663
# w= 0.1 ,b= -1.4999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.3999999999999995,loss_val:11.559999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.2999999999999996,loss_val:28.09
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.1999999999999995,loss_val:51.83999999999999
# MSE= 30.49666666666666
# w= 0.1 ,b= -1.3999999999999995
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.2999999999999994,loss_val:10.889999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.1999999999999995,loss_val:27.039999999999992
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.0999999999999994,loss_val:50.41
# MSE= 29.44666666666666
# w= 0.1 ,b= -1.2999999999999994
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.1999999999999993,loss_val:10.239999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.0999999999999994,loss_val:26.009999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.9999999999999993,loss_val:48.999999999999986
# MSE= 28.416666666666657
# w= 0.1 ,b= -1.1999999999999993
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.0999999999999992,loss_val:9.609999999999996
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.9999999999999993,loss_val:24.999999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.8999999999999992,loss_val:47.60999999999999
# MSE= 27.406666666666656
# w= 0.1 ,b= -1.0999999999999992
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.9999999999999992,loss_val:8.999999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.8999999999999992,loss_val:24.009999999999994
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.7999999999999992,loss_val:46.23999999999999
# MSE= 26.416666666666657
# w= 0.1 ,b= -0.9999999999999991
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.8999999999999991,loss_val:8.409999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.7999999999999992,loss_val:23.03999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.6999999999999991,loss_val:44.88999999999999
# MSE= 25.44666666666666
# w= 0.1 ,b= -0.899999999999999
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.799999999999999,loss_val:7.839999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.6999999999999991,loss_val:22.089999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.599999999999999,loss_val:43.55999999999998
# MSE= 24.496666666666655
# w= 0.1 ,b= -0.7999999999999989
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.699999999999999,loss_val:7.289999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.599999999999999,loss_val:21.15999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.4999999999999989,loss_val:42.249999999999986
# MSE= 23.566666666666652
# w= 0.1 ,b= -0.6999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.5999999999999989,loss_val:6.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.49999999999999883,loss_val:20.249999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.3999999999999988,loss_val:40.95999999999998
# MSE= 22.656666666666656
# w= 0.1 ,b= -0.5999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.4999999999999988,loss_val:6.249999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.39999999999999875,loss_val:19.35999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.2999999999999987,loss_val:39.68999999999998
# MSE= 21.766666666666655
# w= 0.1 ,b= -0.49999999999999867
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.3999999999999987,loss_val:5.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.29999999999999866,loss_val:18.48999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.19999999999999862,loss_val:38.43999999999998
# MSE= 20.896666666666658
# w= 0.1 ,b= -0.3999999999999986
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.2999999999999986,loss_val:5.289999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.19999999999999857,loss_val:17.639999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.09999999999999853,loss_val:37.20999999999999
# MSE= 20.046666666666656
# w= 0.1 ,b= -0.2999999999999985
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.19999999999999848,loss_val:4.839999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.09999999999999848,loss_val:16.809999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.5543122344752192e-15,loss_val:35.99999999999998
# MSE= 19.216666666666654
# w= 0.1 ,b= -0.1999999999999984
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.0999999999999984,loss_val:4.409999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.609823385706477e-15,loss_val:15.999999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.10000000000000164,loss_val:34.80999999999998
# MSE= 18.406666666666652
# w= 0.1 ,b= -0.09999999999999831
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.6930901125533637e-15,loss_val:3.999999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.1000000000000017,loss_val:15.209999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.20000000000000173,loss_val:33.63999999999998
# MSE= 17.616666666666653
# w= 0.1 ,b= 1.7763568394002505e-15
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.10000000000000178,loss_val:3.6099999999999928
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.2000000000000018,loss_val:14.439999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.3000000000000018,loss_val:32.48999999999998
# MSE= 16.846666666666653
# w= 0.1 ,b= 0.10000000000000187
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.20000000000000187,loss_val:3.239999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.3000000000000019,loss_val:13.689999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.4000000000000019,loss_val:31.359999999999975
# MSE= 16.09666666666665
# w= 0.1 ,b= 0.20000000000000195
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.30000000000000193,loss_val:2.889999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.40000000000000197,loss_val:12.959999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.500000000000002,loss_val:30.24999999999998
# MSE= 15.366666666666653
# w= 0.1 ,b= 0.30000000000000204
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.400000000000002,loss_val:2.5599999999999934
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.500000000000002,loss_val:12.249999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.6000000000000021,loss_val:29.159999999999975
# MSE= 14.656666666666652
# w= 0.1 ,b= 0.40000000000000213
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.5000000000000021,loss_val:2.2499999999999933
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.6000000000000021,loss_val:11.559999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.7000000000000022,loss_val:28.08999999999998
# MSE= 13.966666666666653
# w= 0.1 ,b= 0.5000000000000022
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.6000000000000022,loss_val:1.9599999999999935
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.7000000000000022,loss_val:10.889999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.8000000000000023,loss_val:27.039999999999974
# MSE= 13.296666666666653
# w= 0.1 ,b= 0.6000000000000023
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.7000000000000023,loss_val:1.6899999999999937
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.8000000000000023,loss_val:10.239999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.9000000000000024,loss_val:26.009999999999977
# MSE= 12.646666666666652
# w= 0.1 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.8000000000000024,loss_val:1.439999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.9000000000000024,loss_val:9.609999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.0000000000000024,loss_val:24.99999999999997
# MSE= 12.016666666666652
# w= 0.1 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.9000000000000025,loss_val:1.2099999999999944
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.0000000000000024,loss_val:8.999999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.1000000000000025,loss_val:24.009999999999977
# MSE= 11.406666666666652
# w= 0.1 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.0000000000000027,loss_val:0.9999999999999947
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.1000000000000025,loss_val:8.409999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.2000000000000026,loss_val:23.039999999999974
# MSE= 10.81666666666665
# w= 0.1 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.1000000000000028,loss_val:0.8099999999999951
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.2000000000000026,loss_val:7.839999999999984
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.3000000000000027,loss_val:22.089999999999975
# MSE= 10.24666666666665
# w= 0.1 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.2000000000000028,loss_val:0.6399999999999955
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.3000000000000027,loss_val:7.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.4000000000000028,loss_val:21.15999999999997
# MSE= 9.696666666666651
# w= 0.1 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.300000000000003,loss_val:0.4899999999999959
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.4000000000000028,loss_val:6.759999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.5000000000000029,loss_val:20.249999999999975
# MSE= 9.166666666666652
# w= 0.1 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.400000000000003,loss_val:0.3599999999999964
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.5000000000000029,loss_val:6.249999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.600000000000003,loss_val:19.35999999999997
# MSE= 8.656666666666652
# w= 0.1 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.500000000000003,loss_val:0.2499999999999969
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.600000000000003,loss_val:5.759999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.700000000000003,loss_val:18.489999999999977
# MSE= 8.166666666666652
# w= 0.1 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.6000000000000032,loss_val:0.15999999999999745
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.700000000000003,loss_val:5.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.8000000000000032,loss_val:17.639999999999972
# MSE= 7.696666666666652
# w= 0.1 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.7000000000000033,loss_val:0.08999999999999803
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.8000000000000032,loss_val:4.839999999999985
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.9000000000000032,loss_val:16.809999999999974
# MSE= 7.246666666666652
# w= 0.1 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.8000000000000034,loss_val:0.03999999999999865
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.9000000000000032,loss_val:4.409999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.0000000000000036,loss_val:15.999999999999972
# MSE= 6.816666666666652
# w= 0.1 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.9000000000000035,loss_val:0.009999999999999308
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.0000000000000036,loss_val:3.999999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.100000000000003,loss_val:15.209999999999974
# MSE= 6.406666666666653
# w= 0.1 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0000000000000036,loss_val:1.262177448353619e-29
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.1000000000000036,loss_val:3.609999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.2000000000000037,loss_val:14.439999999999971
# MSE= 6.016666666666652
# w= 0.1 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.1000000000000036,loss_val:0.010000000000000729
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.2000000000000037,loss_val:3.2399999999999864
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.3000000000000034,loss_val:13.689999999999975
# MSE= 5.646666666666654
# w= 0.2 ,b= -2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.8,loss_val:14.44
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.6,loss_val:31.359999999999996
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.4,loss_val:54.760000000000005
# MSE= 33.52
# w= 0.2 ,b= -1.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.7,loss_val:13.690000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.5,loss_val:30.25
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.2999999999999998,loss_val:53.29
# MSE= 32.41
# w= 0.2 ,b= -1.7999999999999998
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.5999999999999999,loss_val:12.959999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.4,loss_val:29.160000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.1999999999999997,loss_val:51.83999999999999
# MSE= 31.319999999999997
# w= 0.2 ,b= -1.6999999999999997
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.4999999999999998,loss_val:12.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.2999999999999998,loss_val:28.09
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.0999999999999996,loss_val:50.41
# MSE= 30.25
# w= 0.2 ,b= -1.5999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.3999999999999997,loss_val:11.559999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.1999999999999997,loss_val:27.039999999999992
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.9999999999999996,loss_val:49.0
# MSE= 29.2
# w= 0.2 ,b= -1.4999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.2999999999999996,loss_val:10.889999999999999
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.0999999999999996,loss_val:26.009999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.8999999999999995,loss_val:47.60999999999999
# MSE= 28.169999999999998
# w= 0.2 ,b= -1.3999999999999995
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.1999999999999995,loss_val:10.239999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.9999999999999994,loss_val:24.999999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.7999999999999994,loss_val:46.23999999999999
# MSE= 27.159999999999993
# w= 0.2 ,b= -1.2999999999999994
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.0999999999999994,loss_val:9.609999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.8999999999999994,loss_val:24.009999999999994
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.6999999999999993,loss_val:44.88999999999999
# MSE= 26.169999999999998
# w= 0.2 ,b= -1.1999999999999993
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.9999999999999993,loss_val:8.999999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.7999999999999993,loss_val:23.03999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.5999999999999992,loss_val:43.559999999999995
# MSE= 25.199999999999992
# w= 0.2 ,b= -1.0999999999999992
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.8999999999999992,loss_val:8.409999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.6999999999999992,loss_val:22.089999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.4999999999999991,loss_val:42.249999999999986
# MSE= 24.24999999999999
# w= 0.2 ,b= -0.9999999999999991
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.7999999999999992,loss_val:7.839999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.5999999999999991,loss_val:21.15999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.399999999999999,loss_val:40.95999999999998
# MSE= 23.31999999999999
# w= 0.2 ,b= -0.899999999999999
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.6999999999999991,loss_val:7.2899999999999965
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.499999999999999,loss_val:20.249999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.29999999999999893,loss_val:39.68999999999998
# MSE= 22.409999999999993
# w= 0.2 ,b= -0.7999999999999989
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.599999999999999,loss_val:6.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.3999999999999989,loss_val:19.35999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.19999999999999885,loss_val:38.43999999999999
# MSE= 21.519999999999992
# w= 0.2 ,b= -0.6999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.49999999999999883,loss_val:6.249999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.2999999999999988,loss_val:18.48999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.09999999999999876,loss_val:37.20999999999999
# MSE= 20.64999999999999
# w= 0.2 ,b= -0.5999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.39999999999999875,loss_val:5.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.19999999999999873,loss_val:17.639999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.3322676295501878e-15,loss_val:35.99999999999998
# MSE= 19.799999999999986
# w= 0.2 ,b= -0.49999999999999867
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.29999999999999866,loss_val:5.289999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.09999999999999865,loss_val:16.809999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.10000000000000142,loss_val:34.80999999999998
# MSE= 18.969999999999988
# w= 0.2 ,b= -0.3999999999999986
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.19999999999999857,loss_val:4.839999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.4432899320127035e-15,loss_val:15.99999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.2000000000000015,loss_val:33.639999999999986
# MSE= 18.15999999999999
# w= 0.2 ,b= -0.2999999999999985
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.09999999999999848,loss_val:4.409999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.10000000000000153,loss_val:15.209999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.3000000000000016,loss_val:32.48999999999998
# MSE= 17.369999999999987
# w= 0.2 ,b= -0.1999999999999984
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.609823385706477e-15,loss_val:3.999999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.20000000000000162,loss_val:14.439999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.4000000000000017,loss_val:31.359999999999975
# MSE= 16.599999999999984
# w= 0.2 ,b= -0.09999999999999831
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.1000000000000017,loss_val:3.6099999999999937
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.3000000000000017,loss_val:13.689999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.5000000000000018,loss_val:30.24999999999998
# MSE= 15.849999999999987
# w= 0.2 ,b= 1.7763568394002505e-15
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.2000000000000018,loss_val:3.2399999999999936
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.4000000000000018,loss_val:12.959999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.6000000000000019,loss_val:29.159999999999986
# MSE= 15.11999999999999
# w= 0.2 ,b= 0.10000000000000187
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.3000000000000019,loss_val:2.889999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.5000000000000019,loss_val:12.249999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.700000000000002,loss_val:28.08999999999998
# MSE= 14.409999999999988
# w= 0.2 ,b= 0.20000000000000195
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.40000000000000197,loss_val:2.559999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.600000000000002,loss_val:11.559999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.800000000000002,loss_val:27.039999999999974
# MSE= 13.719999999999985
# w= 0.2 ,b= 0.30000000000000204
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.500000000000002,loss_val:2.249999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.7000000000000021,loss_val:10.889999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.9000000000000021,loss_val:26.009999999999977
# MSE= 13.049999999999985
# w= 0.2 ,b= 0.40000000000000213
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.6000000000000021,loss_val:1.9599999999999942
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.8000000000000022,loss_val:10.239999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.0000000000000022,loss_val:24.999999999999982
# MSE= 12.399999999999986
# w= 0.2 ,b= 0.5000000000000022
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.7000000000000022,loss_val:1.6899999999999944
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.9000000000000022,loss_val:9.609999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.1000000000000023,loss_val:24.009999999999977
# MSE= 11.769999999999987
# w= 0.2 ,b= 0.6000000000000023
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.8000000000000023,loss_val:1.4399999999999946
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.0000000000000022,loss_val:8.999999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.2000000000000024,loss_val:23.039999999999974
# MSE= 11.159999999999984
# w= 0.2 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.9000000000000024,loss_val:1.2099999999999949
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.1000000000000023,loss_val:8.409999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.3000000000000025,loss_val:22.089999999999975
# MSE= 10.569999999999986
# w= 0.2 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.0000000000000024,loss_val:0.9999999999999951
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.2000000000000024,loss_val:7.8399999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.4000000000000026,loss_val:21.15999999999998
# MSE= 9.999999999999988
# w= 0.2 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.1000000000000025,loss_val:0.8099999999999954
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.3000000000000025,loss_val:7.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.5000000000000027,loss_val:20.249999999999975
# MSE= 9.449999999999987
# w= 0.2 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.2000000000000026,loss_val:0.6399999999999958
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.4000000000000026,loss_val:6.7599999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.6000000000000028,loss_val:19.35999999999997
# MSE= 8.919999999999986
# w= 0.2 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.3000000000000027,loss_val:0.4899999999999962
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.5000000000000027,loss_val:6.249999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.7000000000000028,loss_val:18.489999999999977
# MSE= 8.409999999999988
# w= 0.2 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.4000000000000028,loss_val:0.35999999999999666
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.6000000000000028,loss_val:5.7599999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.800000000000003,loss_val:17.63999999999998
# MSE= 7.9199999999999875
# w= 0.2 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.5000000000000029,loss_val:0.2499999999999971
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.7000000000000028,loss_val:5.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.900000000000003,loss_val:16.809999999999974
# MSE= 7.449999999999986
# w= 0.2 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.600000000000003,loss_val:0.15999999999999762
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.800000000000003,loss_val:4.839999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.000000000000003,loss_val:15.999999999999975
# MSE= 6.999999999999987
# w= 0.2 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.700000000000003,loss_val:0.08999999999999816
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.900000000000003,loss_val:4.409999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.100000000000003,loss_val:15.209999999999974
# MSE= 6.569999999999986
# w= 0.2 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.8000000000000032,loss_val:0.03999999999999874
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.000000000000003,loss_val:3.9999999999999876
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.2000000000000033,loss_val:14.439999999999975
# MSE= 6.159999999999987
# w= 0.2 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.9000000000000032,loss_val:0.009999999999999351
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.100000000000003,loss_val:3.609999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.3000000000000034,loss_val:13.689999999999975
# MSE= 5.769999999999988
# w= 0.2 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0000000000000036,loss_val:1.262177448353619e-29
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.2000000000000033,loss_val:3.2399999999999882
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.4000000000000035,loss_val:12.959999999999974
# MSE= 5.399999999999988
# w= 0.2 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.1000000000000036,loss_val:0.010000000000000729
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.3000000000000034,loss_val:2.8899999999999886
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.5000000000000036,loss_val:12.249999999999975
# MSE= 5.049999999999988
# w= 0.2 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.2000000000000037,loss_val:0.04000000000000149
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.4000000000000035,loss_val:2.559999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.6000000000000036,loss_val:11.559999999999976
# MSE= 4.719999999999989
# w= 0.30000000000000004 ,b= -2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.7,loss_val:13.690000000000001
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.4,loss_val:29.160000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:-1.0999999999999999,loss_val:50.41
# MSE= 31.08666666666667
# w= 0.30000000000000004 ,b= -1.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.5999999999999999,loss_val:12.959999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.2999999999999998,loss_val:28.09
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.9999999999999998,loss_val:49.0
# MSE= 30.016666666666666
# w= 0.30000000000000004 ,b= -1.7999999999999998
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.4999999999999998,loss_val:12.25
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.1999999999999997,loss_val:27.039999999999992
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.8999999999999997,loss_val:47.60999999999999
# MSE= 28.966666666666658
# w= 0.30000000000000004 ,b= -1.6999999999999997
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.3999999999999997,loss_val:11.559999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-1.0999999999999996,loss_val:26.009999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.7999999999999996,loss_val:46.239999999999995
# MSE= 27.936666666666664
# w= 0.30000000000000004 ,b= -1.5999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.2999999999999996,loss_val:10.889999999999999
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.9999999999999996,loss_val:25.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.6999999999999995,loss_val:44.88999999999999
# MSE= 26.926666666666666
# w= 0.30000000000000004 ,b= -1.4999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.1999999999999995,loss_val:10.239999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.8999999999999995,loss_val:24.009999999999994
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.5999999999999994,loss_val:43.559999999999995
# MSE= 25.936666666666657
# w= 0.30000000000000004 ,b= -1.3999999999999995
# 	 x_val:1.0,y_val:2.0,y_pred_val:-1.0999999999999994,loss_val:9.609999999999998
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.7999999999999994,loss_val:23.03999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.49999999999999933,loss_val:42.249999999999986
# MSE= 24.966666666666658
# w= 0.30000000000000004 ,b= -1.2999999999999994
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.9999999999999993,loss_val:8.999999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.6999999999999993,loss_val:22.089999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.39999999999999925,loss_val:40.959999999999994
# MSE= 24.016666666666662
# w= 0.30000000000000004 ,b= -1.1999999999999993
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.8999999999999992,loss_val:8.409999999999997
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.5999999999999992,loss_val:21.159999999999997
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.29999999999999916,loss_val:39.68999999999998
# MSE= 23.08666666666666
# w= 0.30000000000000004 ,b= -1.0999999999999992
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.7999999999999992,loss_val:7.839999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.4999999999999991,loss_val:20.249999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.19999999999999907,loss_val:38.43999999999999
# MSE= 22.17666666666666
# w= 0.30000000000000004 ,b= -0.9999999999999991
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.6999999999999991,loss_val:7.2899999999999965
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.399999999999999,loss_val:19.35999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:-0.09999999999999898,loss_val:37.20999999999999
# MSE= 21.286666666666658
# w= 0.30000000000000004 ,b= -0.899999999999999
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.599999999999999,loss_val:6.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.29999999999999893,loss_val:18.48999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.1102230246251565e-15,loss_val:35.99999999999999
# MSE= 20.41666666666666
# w= 0.30000000000000004 ,b= -0.7999999999999989
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.4999999999999989,loss_val:6.249999999999996
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.19999999999999885,loss_val:17.639999999999993
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.1000000000000012,loss_val:34.80999999999998
# MSE= 19.56666666666666
# w= 0.30000000000000004 ,b= -0.6999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.3999999999999988,loss_val:5.759999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:-0.09999999999999876,loss_val:16.809999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.2000000000000013,loss_val:33.639999999999986
# MSE= 18.736666666666654
# w= 0.30000000000000004 ,b= -0.5999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.2999999999999987,loss_val:5.289999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.3322676295501878e-15,loss_val:15.99999999999999
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.3000000000000014,loss_val:32.48999999999998
# MSE= 17.926666666666655
# w= 0.30000000000000004 ,b= -0.49999999999999867
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.19999999999999862,loss_val:4.839999999999993
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.10000000000000142,loss_val:15.209999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.40000000000000147,loss_val:31.359999999999985
# MSE= 17.136666666666656
# w= 0.30000000000000004 ,b= -0.3999999999999986
# 	 x_val:1.0,y_val:2.0,y_pred_val:-0.09999999999999853,loss_val:4.409999999999995
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.2000000000000015,loss_val:14.439999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.5000000000000016,loss_val:30.24999999999998
# MSE= 16.366666666666656
# w= 0.30000000000000004 ,b= -0.2999999999999985
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.5543122344752192e-15,loss_val:3.999999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.3000000000000016,loss_val:13.689999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.6000000000000016,loss_val:29.159999999999986
# MSE= 15.616666666666655
# w= 0.30000000000000004 ,b= -0.1999999999999984
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.10000000000000164,loss_val:3.6099999999999937
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.4000000000000017,loss_val:12.959999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.7000000000000017,loss_val:28.08999999999998
# MSE= 14.886666666666654
# w= 0.30000000000000004 ,b= -0.09999999999999831
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.20000000000000173,loss_val:3.2399999999999936
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.5000000000000018,loss_val:12.249999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.8000000000000018,loss_val:27.039999999999985
# MSE= 14.176666666666655
# w= 0.30000000000000004 ,b= 1.7763568394002505e-15
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.3000000000000018,loss_val:2.889999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.6000000000000019,loss_val:11.559999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:0.9000000000000019,loss_val:26.009999999999977
# MSE= 13.486666666666652
# w= 0.30000000000000004 ,b= 0.10000000000000187
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.4000000000000019,loss_val:2.559999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.700000000000002,loss_val:10.889999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.000000000000002,loss_val:24.999999999999982
# MSE= 12.816666666666654
# w= 0.30000000000000004 ,b= 0.20000000000000195
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.500000000000002,loss_val:2.249999999999994
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.800000000000002,loss_val:10.239999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.100000000000002,loss_val:24.009999999999977
# MSE= 12.166666666666652
# w= 0.30000000000000004 ,b= 0.30000000000000204
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.6000000000000021,loss_val:1.9599999999999942
# 	 x_val:2.0,y_val:4.0,y_pred_val:0.9000000000000021,loss_val:9.609999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.2000000000000022,loss_val:23.03999999999998
# MSE= 11.536666666666655
# w= 0.30000000000000004 ,b= 0.40000000000000213
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.7000000000000022,loss_val:1.6899999999999944
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.0000000000000022,loss_val:8.999999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.3000000000000023,loss_val:22.089999999999975
# MSE= 10.926666666666653
# w= 0.30000000000000004 ,b= 0.5000000000000022
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.8000000000000023,loss_val:1.4399999999999946
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.1000000000000023,loss_val:8.409999999999986
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.4000000000000024,loss_val:21.15999999999998
# MSE= 10.336666666666654
# w= 0.30000000000000004 ,b= 0.6000000000000023
# 	 x_val:1.0,y_val:2.0,y_pred_val:0.9000000000000024,loss_val:1.2099999999999949
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.2000000000000024,loss_val:7.8399999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.5000000000000024,loss_val:20.249999999999975
# MSE= 9.766666666666652
# w= 0.30000000000000004 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.0000000000000024,loss_val:0.9999999999999951
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.3000000000000025,loss_val:7.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.6000000000000025,loss_val:19.359999999999978
# MSE= 9.216666666666653
# w= 0.30000000000000004 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.1000000000000025,loss_val:0.8099999999999954
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.4000000000000026,loss_val:6.7599999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.7000000000000026,loss_val:18.489999999999977
# MSE= 8.686666666666653
# w= 0.30000000000000004 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.2000000000000026,loss_val:0.6399999999999958
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.5000000000000027,loss_val:6.249999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.8000000000000027,loss_val:17.63999999999998
# MSE= 8.176666666666653
# w= 0.30000000000000004 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.3000000000000027,loss_val:0.4899999999999962
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.6000000000000028,loss_val:5.7599999999999865
# 	 x_val:3.0,y_val:6.0,y_pred_val:1.9000000000000028,loss_val:16.809999999999974
# MSE= 7.686666666666652
# w= 0.30000000000000004 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.4000000000000028,loss_val:0.35999999999999666
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.7000000000000028,loss_val:5.289999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.0000000000000027,loss_val:15.999999999999979
# MSE= 7.216666666666654
# w= 0.30000000000000004 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.5000000000000029,loss_val:0.2499999999999971
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.800000000000003,loss_val:4.839999999999987
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.100000000000003,loss_val:15.209999999999974
# MSE= 6.766666666666652
# w= 0.30000000000000004 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.600000000000003,loss_val:0.15999999999999762
# 	 x_val:2.0,y_val:4.0,y_pred_val:1.900000000000003,loss_val:4.409999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.200000000000003,loss_val:14.439999999999978
# MSE= 6.3366666666666545
# w= 0.30000000000000004 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.700000000000003,loss_val:0.08999999999999816
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.000000000000003,loss_val:3.9999999999999876
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.3000000000000034,loss_val:13.689999999999975
# MSE= 5.9266666666666525
# w= 0.30000000000000004 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.8000000000000032,loss_val:0.03999999999999874
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.100000000000003,loss_val:3.609999999999988
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.400000000000003,loss_val:12.959999999999978
# MSE= 5.536666666666655
# w= 0.30000000000000004 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:1.9000000000000032,loss_val:0.009999999999999351
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.2000000000000033,loss_val:3.2399999999999882
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.5000000000000036,loss_val:12.249999999999975
# MSE= 5.1666666666666545
# w= 0.30000000000000004 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0000000000000036,loss_val:1.262177448353619e-29
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.3000000000000034,loss_val:2.8899999999999886
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.600000000000003,loss_val:11.559999999999977
# MSE= 4.816666666666655
# w= 0.30000000000000004 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.100000000000003,loss_val:0.01000000000000064
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.4000000000000035,loss_val:2.559999999999989
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.7000000000000037,loss_val:10.889999999999976
# MSE= 4.486666666666655
# w= 0.30000000000000004 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.2000000000000037,loss_val:0.04000000000000149
# 	 x_val:2.0,y_val:4.0,y_pred_val:2.5000000000000036,loss_val:2.2499999999999893
# 	 x_val:3.0,y_val:6.0,y_pred_val:2.8000000000000034,loss_val:10.239999999999979
# MSE= 4.176666666666656
# w= 0.30000000000000004 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.3000000000000034,loss_val:0.09000000000000202
# ...
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.400000000000002,loss_val:19.360000000000017
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.300000000000004,loss_val:39.690000000000055
# MSE= 21.766666666666694
# w= 3.9000000000000004 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.600000000000003,loss_val:6.760000000000017
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.500000000000004,loss_val:20.250000000000032
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.400000000000004,loss_val:40.96000000000005
# MSE= 22.6566666666667
# w= 3.9000000000000004 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.700000000000003,loss_val:7.290000000000015
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.600000000000003,loss_val:21.16000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.500000000000004,loss_val:42.25000000000004
# MSE= 23.566666666666695
# w= 3.9000000000000004 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.8000000000000025,loss_val:7.840000000000014
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.700000000000003,loss_val:22.09000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.600000000000003,loss_val:43.560000000000045
# MSE= 24.496666666666698
# w= 3.9000000000000004 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.900000000000003,loss_val:8.410000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.800000000000004,loss_val:23.040000000000042
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.700000000000003,loss_val:44.890000000000036
# MSE= 25.446666666666697
# w= 3.9000000000000004 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.0000000000000036,loss_val:9.000000000000021
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.900000000000004,loss_val:24.010000000000037
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.800000000000004,loss_val:46.24000000000006
# MSE= 26.416666666666703
# w= 3.9000000000000004 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.100000000000003,loss_val:9.610000000000019
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.000000000000004,loss_val:25.000000000000036
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.900000000000004,loss_val:47.610000000000056
# MSE= 27.406666666666705
# w= 3.9000000000000004 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.200000000000003,loss_val:10.240000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.100000000000003,loss_val:26.010000000000034
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.000000000000004,loss_val:49.00000000000005
# MSE= 28.4166666666667
# w= 3.9000000000000004 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.300000000000003,loss_val:10.890000000000022
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.200000000000003,loss_val:27.04000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.100000000000005,loss_val:50.41000000000007
# MSE= 29.446666666666705
# w= 3.9000000000000004 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.400000000000004,loss_val:11.560000000000027
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.300000000000004,loss_val:28.090000000000046
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.200000000000005,loss_val:51.84000000000007
# MSE= 30.496666666666716
# w= 3.9000000000000004 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.5000000000000036,loss_val:12.250000000000025
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.400000000000004,loss_val:29.160000000000043
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.300000000000004,loss_val:53.29000000000006
# MSE= 31.56666666666671
# w= 3.9000000000000004 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.600000000000003,loss_val:12.960000000000022
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.500000000000004,loss_val:30.25000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.400000000000004,loss_val:54.760000000000055
# MSE= 32.6566666666667
# w= 3.9000000000000004 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.700000000000004,loss_val:13.690000000000028
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.600000000000005,loss_val:31.360000000000056
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.500000000000004,loss_val:56.25000000000006
# MSE= 33.766666666666715
# w= 3.9000000000000004 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.800000000000004,loss_val:14.440000000000033
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.700000000000005,loss_val:32.49000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.600000000000005,loss_val:57.760000000000076
# MSE= 34.896666666666725
# w= 3.9000000000000004 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.900000000000004,loss_val:15.210000000000031
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.800000000000004,loss_val:33.64000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.700000000000005,loss_val:59.29000000000007
# MSE= 36.04666666666672
# w= 4.0 ,b= -2.0
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.0,loss_val:0.0
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.0,loss_val:4.0
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.0,loss_val:16.0
# MSE= 6.666666666666667
# w= 4.0 ,b= -1.9
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.1,loss_val:0.010000000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.1,loss_val:4.409999999999998
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.1,loss_val:16.81
# MSE= 7.076666666666665
# w= 4.0 ,b= -1.7999999999999998
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.2,loss_val:0.04000000000000007
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.2,loss_val:4.840000000000001
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.2,loss_val:17.639999999999993
# MSE= 7.506666666666665
# w= 4.0 ,b= -1.6999999999999997
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.3000000000000003,loss_val:0.09000000000000016
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.300000000000001,loss_val:5.290000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.3,loss_val:18.490000000000006
# MSE= 7.95666666666667
# w= 4.0 ,b= -1.5999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.4000000000000004,loss_val:0.16000000000000028
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.4,loss_val:5.760000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.4,loss_val:19.360000000000003
# MSE= 8.426666666666668
# w= 4.0 ,b= -1.4999999999999996
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.5000000000000004,loss_val:0.25000000000000044
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.5,loss_val:6.25
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.5,loss_val:20.25
# MSE= 8.916666666666666
# w= 4.0 ,b= -1.3999999999999995
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.6000000000000005,loss_val:0.36000000000000065
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.6000000000000005,loss_val:6.7600000000000025
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.600000000000001,loss_val:21.160000000000014
# MSE= 9.426666666666671
# w= 4.0 ,b= -1.2999999999999994
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.7000000000000006,loss_val:0.4900000000000009
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.700000000000001,loss_val:7.290000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.700000000000001,loss_val:22.09000000000001
# MSE= 9.956666666666672
# w= 4.0 ,b= -1.1999999999999993
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.8000000000000007,loss_val:0.6400000000000011
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.800000000000001,loss_val:7.840000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.8,loss_val:23.040000000000006
# MSE= 10.50666666666667
# w= 4.0 ,b= -1.0999999999999992
# 	 x_val:1.0,y_val:2.0,y_pred_val:2.900000000000001,loss_val:0.8100000000000014
# 	 x_val:2.0,y_val:4.0,y_pred_val:6.9,loss_val:8.410000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:10.9,loss_val:24.010000000000005
# MSE= 11.076666666666668
# w= 4.0 ,b= -0.9999999999999991
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.000000000000001,loss_val:1.0000000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.000000000000001,loss_val:9.000000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.0,loss_val:25.0
# MSE= 11.66666666666667
# w= 4.0 ,b= -0.899999999999999
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.100000000000001,loss_val:1.2100000000000022
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.100000000000001,loss_val:9.610000000000008
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.100000000000001,loss_val:26.010000000000016
# MSE= 12.276666666666676
# w= 4.0 ,b= -0.7999999999999989
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.200000000000001,loss_val:1.4400000000000026
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.200000000000001,loss_val:10.240000000000007
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.200000000000001,loss_val:27.04000000000001
# MSE= 12.906666666666673
# w= 4.0 ,b= -0.6999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.300000000000001,loss_val:1.690000000000003
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.300000000000001,loss_val:10.890000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.3,loss_val:28.090000000000007
# MSE= 13.556666666666672
# w= 4.0 ,b= -0.5999999999999988
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.4000000000000012,loss_val:1.9600000000000035
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.400000000000001,loss_val:11.560000000000008
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.400000000000002,loss_val:29.16000000000002
# MSE= 14.226666666666679
# w= 4.0 ,b= -0.49999999999999867
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.5000000000000013,loss_val:2.250000000000004
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.500000000000002,loss_val:12.250000000000012
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.500000000000002,loss_val:30.25000000000002
# MSE= 14.916666666666679
# w= 4.0 ,b= -0.3999999999999986
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.6000000000000014,loss_val:2.5600000000000045
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.600000000000001,loss_val:12.96000000000001
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.600000000000001,loss_val:31.360000000000017
# MSE= 15.626666666666678
# w= 4.0 ,b= -0.2999999999999985
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.7000000000000015,loss_val:2.890000000000005
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.700000000000001,loss_val:13.690000000000008
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.700000000000001,loss_val:32.49000000000001
# MSE= 16.356666666666673
# w= 4.0 ,b= -0.1999999999999984
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.8000000000000016,loss_val:3.2400000000000055
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.800000000000002,loss_val:14.440000000000012
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.8,loss_val:33.64000000000001
# MSE= 17.106666666666673
# w= 4.0 ,b= -0.09999999999999831
# 	 x_val:1.0,y_val:2.0,y_pred_val:3.9000000000000017,loss_val:3.6100000000000065
# 	 x_val:2.0,y_val:4.0,y_pred_val:7.900000000000002,loss_val:15.210000000000017
# 	 x_val:3.0,y_val:6.0,y_pred_val:11.900000000000002,loss_val:34.810000000000024
# MSE= 17.876666666666683
# w= 4.0 ,b= 1.7763568394002505e-15
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.000000000000002,loss_val:4.000000000000007
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.000000000000002,loss_val:16.000000000000014
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.000000000000002,loss_val:36.00000000000002
# MSE= 18.666666666666682
# w= 4.0 ,b= 0.10000000000000187
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.100000000000001,loss_val:4.410000000000006
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.100000000000001,loss_val:16.810000000000013
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.100000000000001,loss_val:37.210000000000015
# MSE= 19.476666666666677
# w= 4.0 ,b= 0.20000000000000195
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.200000000000002,loss_val:4.840000000000009
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.200000000000003,loss_val:17.640000000000025
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.200000000000003,loss_val:38.44000000000003
# MSE= 20.30666666666669
# w= 4.0 ,b= 0.30000000000000204
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.3000000000000025,loss_val:5.290000000000012
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.300000000000002,loss_val:18.49000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.300000000000002,loss_val:39.69000000000003
# MSE= 21.156666666666688
# w= 4.0 ,b= 0.40000000000000213
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.400000000000002,loss_val:5.7600000000000104
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.400000000000002,loss_val:19.360000000000017
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.400000000000002,loss_val:40.96000000000003
# MSE= 22.026666666666685
# w= 4.0 ,b= 0.5000000000000022
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.500000000000002,loss_val:6.250000000000009
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.500000000000002,loss_val:20.250000000000018
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.500000000000002,loss_val:42.25000000000002
# MSE= 22.916666666666686
# w= 4.0 ,b= 0.6000000000000023
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.600000000000002,loss_val:6.760000000000012
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.600000000000001,loss_val:21.160000000000014
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.600000000000001,loss_val:43.56000000000002
# MSE= 23.826666666666682
# w= 4.0 ,b= 0.7000000000000024
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.700000000000003,loss_val:7.290000000000015
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.700000000000003,loss_val:22.09000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.700000000000003,loss_val:44.890000000000036
# MSE= 24.756666666666693
# w= 4.0 ,b= 0.8000000000000025
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.8000000000000025,loss_val:7.840000000000014
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.800000000000002,loss_val:23.040000000000024
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.800000000000002,loss_val:46.24000000000003
# MSE= 25.70666666666669
# w= 4.0 ,b= 0.9000000000000026
# 	 x_val:1.0,y_val:2.0,y_pred_val:4.900000000000002,loss_val:8.410000000000013
# 	 x_val:2.0,y_val:4.0,y_pred_val:8.900000000000002,loss_val:24.01000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:12.900000000000002,loss_val:47.61000000000003
# MSE= 26.676666666666687
# w= 4.0 ,b= 1.0000000000000027
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.000000000000003,loss_val:9.000000000000016
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.000000000000004,loss_val:25.000000000000036
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.000000000000004,loss_val:49.00000000000005
# MSE= 27.6666666666667
# w= 4.0 ,b= 1.1000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.100000000000003,loss_val:9.610000000000019
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.100000000000003,loss_val:26.010000000000034
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.100000000000003,loss_val:50.410000000000046
# MSE= 28.6766666666667
# w= 4.0 ,b= 1.2000000000000028
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.200000000000003,loss_val:10.240000000000018
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.200000000000003,loss_val:27.04000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.200000000000003,loss_val:51.84000000000004
# MSE= 29.706666666666695
# w= 4.0 ,b= 1.300000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.3000000000000025,loss_val:10.890000000000017
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.300000000000002,loss_val:28.090000000000025
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.300000000000002,loss_val:53.290000000000035
# MSE= 30.75666666666669
# w= 4.0 ,b= 1.400000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.400000000000003,loss_val:11.56000000000002
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.400000000000002,loss_val:29.16000000000002
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.400000000000002,loss_val:54.76000000000003
# MSE= 31.826666666666693
# w= 4.0 ,b= 1.500000000000003
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.5000000000000036,loss_val:12.250000000000025
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.500000000000004,loss_val:30.25000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.500000000000004,loss_val:56.25000000000006
# MSE= 32.91666666666671
# w= 4.0 ,b= 1.6000000000000032
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.600000000000003,loss_val:12.960000000000022
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.600000000000003,loss_val:31.360000000000035
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.600000000000003,loss_val:57.76000000000005
# MSE= 34.0266666666667
# w= 4.0 ,b= 1.7000000000000033
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.700000000000003,loss_val:13.69000000000002
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.700000000000003,loss_val:32.49000000000003
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.700000000000003,loss_val:59.29000000000004
# MSE= 35.156666666666695
# w= 4.0 ,b= 1.8000000000000034
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.800000000000003,loss_val:14.440000000000026
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.800000000000004,loss_val:33.64000000000005
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.800000000000004,loss_val:60.84000000000007
# MSE= 36.306666666666715
# w= 4.0 ,b= 1.9000000000000035
# 	 x_val:1.0,y_val:2.0,y_pred_val:5.900000000000004,loss_val:15.210000000000031
# 	 x_val:2.0,y_val:4.0,y_pred_val:9.900000000000004,loss_val:34.810000000000045
# 	 x_val:3.0,y_val:6.0,y_pred_val:13.900000000000004,loss_val:62.41000000000006
# MSE= 37.47666666666671
# w= 4.0 ,b= 2.0000000000000036
# 	 x_val:1.0,y_val:2.0,y_pred_val:6.0000000000000036,loss_val:16.00000000000003
# 	 x_val:2.0,y_val:4.0,y_pred_val:10.000000000000004,loss_val:36.00000000000004
# 	 x_val:3.0,y_val:6.0,y_pred_val:14.000000000000004,loss_val:64.00000000000006
# MSE= 38.66666666666671

# %% [markdown]
# ## meshgrid 3维绘图

# %%
W,B = np.meshgrid(np.array(w_list), np.array(b_list))
print(W.shape, B.shape, np.array(mse_list).shape)
# Out:
# (1681, 1681) (1681, 1681) (1681,)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')
w_range = np.arange(0.0, 4.1, 0.1)
b_range = np.arange(-2.0, 2.1, 0.1)
W, B = np.meshgrid(w_range, b_range) 
mse_array = np.array(mse_list)
mse_array = mse_array.reshape(W.shape)

# 直接拿结果来meshgrid是不对的，因为w_list和b_lis是一维的，都是41*41个，
# 所以meshgrid后他们的shape是(41*41,41*41)，而mse_list是(1681,)，所以这就是为什么会报错的原因
# 错误做法：
# # W,B = np.meshgrid(np.array(w_list), np.array(b_list))
# mse_array = np.array(mse_list).reshape(B.shape)  # 自动匹配形状
# 3D 折线
# ax.plot(w_list,b_list,mse_list)
# 3D 散点
# ax.scatter3D(w_list,b_list,mse_list)
ax.plot_surface(W,B,mse_array, edgecolor='none',
                 rstride=1,##retride(row)指定行的跨度
                    cstride=1,##retride(column)指定列的跨度
                    cmap='rainbow', # 颜色
                    alpha=0.3) # 透明度要低一点。
ax.set_xlabel('w')
ax.set_ylabel('b')
ax.set_zlabel('MSE Loss')
plt.show()
# Out:
# Text(0.5, 0, 'w')
# Text(0.5, 0.5, 'b')
# Text(0.5, 0, 'MSE Loss')

# %% [markdown]
# ### 2.1 绘画y = w*x +b 的3维损失图

# %%
import numpy as np
import matplotlib.pyplot as plt

x_data = np.array([1.0,2.0,3.0])
y_data = np.array([2.0,4.0,6.0])

def forward(x):
    return x * w + b

def loss(x,y):
    y_pred = forward(x)
    return (y_pred - y)**2


# x,y为输入的样本，w,b为模型的参数
def compute_gradients(x_data, y_data, w, b):
    # 计算损失函数对w的梯度
    # 计算损失函数对b的梯度
    # 计算损失的总和

    y_pred = w * x_data + b
    grad_w = np.sum(2 * (y_pred - y_data) * x_data)
    grad_b = np.sum(2 * (y_pred - y_data))
    sum_loss = np.sum((y_pred - y_data)**2)
    return np.array([grad_w, grad_b]),sum_loss

# 梯度下降过程计算两个参数w,b的列表
def gradient_descent(grad,x_data,y_data, learning_rate=0.01, precision=0.001, max_iters=1000):

    # 重新初始化w,b 尽量使用np数组
    init_wb = np.array([4.0, 2.0])
    gd_w_list = []
    gd_b_list = []
    gd_sum_loss_list = []

    # 优化的目标是sum_loss最小
    for i in range(max_iters):
        # 将初始化的w,b赋值给变量w,b
        w, b = init_wb
        # 输入就是x_data和y_data
        grad_val, sum_loss_val = grad(x_data, y_data, w, b)
        # 比较好的操作：
        # 1.返回如果是 np.array([grad_w, grad_b]),sum_loss
        # grad_val, sum_loss_val = grad()解包后，grad_val类型不变

        # 2.返回如果是 np.array([grad_w, grad_b，sum_loss])
        # 解包前两个在一块，最后一个单独，就会改变grad_val的类型为list
        # *grad_val, sum_loss_val = grad()解包后，grad_val类型改变。
        
        # 当梯度接近0，视为收敛
        if np.linalg.norm(grad_val,ord=2)<precision:
            break

        # 迭代w,b
        init_wb -= learning_rate*grad_val

        # 记录w,b,sum_loss
        gd_b_list.append(b)
        gd_w_list.append(w)
        gd_sum_loss_list.append(sum_loss_val/len(x_data))
    # 因为要画图，所以最好返回np.array类型
    return np.array(gd_w_list), np.array(gd_b_list), np.array(gd_sum_loss_list)
w_list = []
b_list = []
mse_list = []

for w in np.arange(0.0,4.1,0.1):
    for b in np.arange(-2,2.1,0.1):
        # print('w=',w,',b=',b)
        l_sum = 0
        for x_val,y_val in zip(x_data,y_data):
            y_pred_val = forward(x_val)
            loss_val = loss(x_val,y_val)
            l_sum += loss_val
            # print(f'\t x_val:{x_val},y_val:{y_val},y_pred_val:{y_pred_val},loss_val:{loss_val}')
            
        # print(f'MSE=',l_sum/len(x_data))
        w_list.append(w)
        b_list.append(b)
        mse_list.append(l_sum/len(x_data))

# %% [markdown]
# ### 绘画梯度下降和3D面积图

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
# 显示图片
# %matplotlib inline
fig = plt.figure()
ax = plt.axes(projection='3d')

# 梯度下降线图
gd_w_list, gd_b_list, gd_sum_loss_list = gradient_descent(compute_gradients,x_data,y_data)
ax.scatter(gd_w_list, gd_b_list, gd_sum_loss_list, 'red',marker='o',s=10)
# print('gd_w_list=',gd_w_list,',gd_b_list=',gd_b_list,',gd_sum_loss_list=',gd_sum_loss_list)

# 3D面积图

w_range = np.arange(0.0, 4.1, 0.1)
b_range = np.arange(-2.0, 2.1, 0.1)
# print('w_range=',w_range,',b_range=',b_range)

W, B = np.meshgrid(w_range, b_range) 
print(W.shape, B.shape)
# [length(b_range), length(w_range)]
mse_array = np.array(mse_list)
# 外层是 w，内层是 b
# 所以 mse_list 的顺序是：w 变得慢，b 变得快
# 因为我们上面迭代是外层w,内层b，所以Reshape只能先(len(w), len(b))
# 而 reshape((len(w), len(b))) 会生成一个 (w_steps, b_steps) 的矩阵
# 但 np.meshgrid(w_range, b_range) 默认是 indexing='xy'，返回 (len(b_range), len(w_range)) 形状
# 也就是说，meshgrid的第一个维度是b，第二个维度是w 点，空间中的点应该是(b,w,mse)这种维度
# 而实际我们需要的是(w,b,mse)这种维度，所以我们需要转置一下

mse_array = mse_array.reshape(W.shape).T
# print('mse_array',mse_array)

# 直接拿结果来meshgrid是不对的，因为w_list和b_lis是一维的，都是41*41个，
# 所以meshgrid后他们的shape是(41*41,41*41)，而mse_list是(1681,)，所以这就是为什么会报错的原因
# 错误做法：
# # W,B = np.meshgrid(np.array(w_list), np.array(b_list))
# mse_array = np.array(mse_list).reshape(B.shape)  # 自动匹配形状
# 3D 折线
# ax.plot(w_list,b_list,mse_list)
# 3D 散点
# ax.scatter3D(w_list,b_list,mse_list)
ax.plot_surface(W,B,mse_array, edgecolor='none',
                 rstride=1,##retride(row)指定行的跨度
                    cstride=1,##retride(column)指定列的跨度
                    cmap='rainbow', # 颜色
                    alpha=0.3) # 透明度要低一点。
ax.set_xlabel('w')
ax.set_ylabel('b')
ax.set_zlabel('MSE Loss')
plt.show()
# Out:
# (41, 41) (41, 41)
# Text(0.5, 0, 'w')
# Text(0.5, 0.5, 'b')
# Text(0.5, 0, 'MSE Loss')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

print('mse_array',mse_array)
print('hhhh')
# Out:
# mse_array [[38.66666667 37.47666667 36.30666667 ...  7.50666667  7.07666667
#    6.66666667]
#  [36.04666667 34.89666667 33.76666667 ...  6.40666667  6.01666667
#    5.64666667]
#  [33.52       32.41       31.32       ...  5.4         5.05
#    4.72      ]
#  ...
#  [ 4.72        5.05        5.4        ... 31.32       32.41
#   33.52      ]
#  [ 5.64666667  6.01666667  6.40666667 ... 33.76666667 34.89666667
#   36.04666667]
#  [ 6.66666667  7.07666667  7.50666667 ... 36.30666667 37.47666667
#   38.66666667]]
# hhhh
