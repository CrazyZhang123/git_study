# %%
from  numpy import random

N = 500 # 样本的数量
d = 300 # 每个样本的维度
c = 5 # 具体的分类数量

W = random.randn(c,d)
wordvectors_list = [random.rand(d,1) for i in range(N)]
wordvectors_one_matrix = random.rand(d,N)

# 循环遍历词向量计算的时间
# %timeit [W.dot(wordvectors_list[i]) for i in range(N)]
# 拼接成大矩阵后批量计算 Softmax 权重的时间
# %timeit W.dot(wordvectors_one_matrix)
# Out:
# 489 μs ± 23.2 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
# 42.7 μs ± 2.29 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 在当前单元格或上一个单元格中执行代码时 Kernel 崩溃。
#
# 请查看单元格中的代码，以确定故障的可能原因。
#
# 单击<a href='https://aka.ms/vscodeJupyterKernelCrash'>此处</a>了解详细信息。
#
# 有关更多详细信息，请查看 Jupyter <a href='command:jupyter.viewOutput'>log</a>。
